# %%
import numpy as np
import pandas as pd
import sys
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re

# %%
hall=pd.read_csv('data.csv')

# %%
df=hall.copy()

# %%
df= df[df['place']=='콘서트홀']

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 0        50.0      F                골드                무료                그린
# 4        50.0      M                무료               NaN               NaN
# 5        30.0      F                블루                무료               NaN
# 6         NaN    NaN               NaN               NaN               NaN
# 7         NaN    NaN               NaN               NaN               NaN
# ...       ...    ...               ...               ...               ...
# 1920853  60.0      F                무료                그린               NaN
# 1920855  50.0      M                무료               NaN               NaN
# 1920856   NaN    NaN               NaN               NaN               NaN
# 1920858   NaN    NaN               NaN               NaN               NaN
# 1920864  20.0      F                무료              싹틔우미               NaN
#
# ...

# %%
df['discount_type']
# Out:
# array(['일반', '블루회원 할인20%', '초대권', 'K-lang 멤버십 회원(1인2매)20%', '골드회원 할인30%',
#        '기획사판매', '싹틔우미 할인40%', '라흐마니노프탄생150주년(8매/3.27까지)20%', '골드회원 할인10%',
#        '장애인/국가유공자 할인50%', '싹딜가(골드)50%', '그린회원 할인5%', '초,중,고,대학생(본인만)30%',
#        '조기예매 할인40%', '그린회원 할인20%', '한화초대석', '단체100인이상50%', '공연예매권',
#        '초/중/고등학생 할인(본인만)30%', '골드회원 할인25%', '우리카드 우수회원', '골드회원 할인20%',
#        '조기예매 할인(1인8매/3월11일까지)30%', '기획사', '신세계석', '골드회원 할인5%', '정기회원',
#        '만65세 이상(본인만)50%', '싹딜가(블루)50%', '공연진행석', '그린회원 할인15%',
#        '직장인 할인(1인2매)20%', '블루회원 할인10%', '초/중/고/대학생 할인(본인만)50%',
#        '문화릴레이(1인2매/공연유료티켓제시)10%', '조기예매 할인10%', 'K-Lang 할인(1인2매)20%',
#        '골드회원 할인40%', '초/중/고등학생 할인(본인만)20%', '조기예매 할인(1인2매/~10월31일까지)30%',
#        '기업석', '초/중/고/대학생 할인30%', '의사상자(동반1인/신분증지참)50%',
#        '초,중,고,대학생(본인만)50%', '조기예매할인(1인8매/~6.30까지)30%', '그린회원 할인10%',
#        '블루회원 할인5%', '스탭 할인30%', '홍보진행', 'KOSYMI  유료회원(1인4매)40%',
#        '청소년(만 24세 이하/본인만)30%', '얼리버드 할인(1인4매/10월31일까지)10%',
# ...

# %%
def extract_percentage(value):
    match = re.search(r'(\d+)/(\d+)', value)
    if match:
        return int(match.group(1))
    return None

# %%
df['discount_type'].apply(extract_percentage).unique()
# Out:
# array([nan,  6.,  7.])

# %%
df[df['discount_type'].apply(extract_percentage)==7]['tran_date']
# Out:
# 52175      20220712
# 63531      20220717
# 113306     20220713
# 146993     20220718
# 222730     20220717
# 238512     20220707
# 376025     20220718
# 378456     20220714
# 412316     20220709
# 415816     20220710
# 520436     20220710
# 711770     20220709
# 906507     20220711
# 915983     20220715
# 1016270    20220708
# 1053461    20220713
# 1064288    20220714
# 1100164    20220713
# 1139360    20220715
# 1175414    20220707
# 1226060    20220709
# 1307267    20220705
# 1313658    20220709
# 1341052    20220708
# 1424749    20220714
# 1428133    20220718
# 1436449    20220713
# 1484041    20220709
# 1489745    20220708
# 1654420    20220710
# 1693279    20220707
# 1697151    20220708
# 1790079    20220712
# 1833230    20220709
# 1838500    20220713
# 1861272    20220707
# Name: tran_date, dtype: int64

# %%
def extract_percentage(value):
    match = re.search(r'(\d+)세', value)
    if match:
        return int(match.group(1))
    return None

# %%
df['discount_type'].apply(extract_percentage).unique()
# Out:
# array([nan, 65., 24.,  7.,  8., 18., 29., 70., 13.])

# %%
df[df['discount_type'].apply(extract_percentage)==18]['discount_type'].unique()
# Out:
# array(['청소년(18세 이하)20%'], dtype=object)

# %%
df[df['discount_type'].apply(extract_percentage)==18][df[df['discount_type'].apply(extract_percentage)==18]['age']>=30]
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 140236   50.0      M                골드                무료                그린
# 473338   40.0      F                무료               NaN               NaN
# 1509473  40.0      F                골드                무료               NaN
# 1525101  50.0      M                골드                무료               NaN
#
#         membership_type_4 membership_type_5  membership_type_6  tran_date  \
# 140236                NaN               NaN                NaN   20190810
# 473338                NaN               NaN                NaN   20190824
# 1509473               NaN               NaN                NaN   20190907
# 1525101               NaN               NaN                NaN   20190824
#
#          tran_time  play_date  play_st_time          seat  price  \
# 140236        1000   20190913          2000  1층 D블록20열 14  16000
# 473338        1342   20190913          2000   1층 E블록15열 3  16000
# ...

# %%
df[df['discount_type'].apply(extract_percentage)==24][df[df['discount_type'].apply(extract_percentage)==24]['age']>=40]
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 25623    50.0      F                무료               NaN               NaN
# 59583    50.0      M                블루                무료                그린
# 75287    50.0      F                무료               NaN               NaN
# 91090    40.0      F                무료               NaN               NaN
# 159250   40.0      F                무료               NaN               NaN
# 182631   50.0      F                무료               NaN               NaN
# 197563   40.0      F                무료               NaN               NaN
# 200096   50.0      F                무료                그린               NaN
# 208691   50.0      M                블루                무료                그린
# 236255   50.0      F                블루                무료                그린
# 281225   50.0      F                무료               NaN               NaN
# ...

# %%
df[df['discount_type'].apply(extract_percentage)==29][df[df['discount_type'].apply(extract_percentage)==29]['age']>=40]
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 38616    40.0      F                블루                골드                무료
# 56299    50.0      F                블루                골드                무료
# 81550    40.0      F                무료               NaN               NaN
# 110200   50.0      F                블루                골드                무료
# 150755   60.0      M                무료               NaN               NaN
# 208402   40.0      F                무료               NaN               NaN
# 261711   40.0      M                무료               NaN               NaN
# 346724   50.0      M                무료               NaN               NaN
# 357712   40.0      F                무료               NaN               NaN
# 422944   40.0      M                무료               NaN               NaN
# 569967   80.0      F                골드                무료                노블
# ...

# %%
df[df['discount_type'].apply(extract_percentage)==65][df[df['discount_type'].apply(extract_percentage)==65]['age']<=50]
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 938      50.0      F                무료               NaN               NaN
# 1978     40.0      M                골드                무료               NaN
# 2170     40.0      F                무료               NaN               NaN
# 2721     40.0      F                골드                무료                그린
# 3367     40.0      F                블루                골드                무료
# ...       ...    ...               ...               ...               ...
# 1914147  40.0      M                블루                골드                무료
# 1915254  40.0      F                골드                무료                그린
# 1916217  40.0      F                무료               NaN               NaN
# 1916760  40.0      M                블루                골드                무료
# 1920499  50.0      F                블루                골드                무료
#
# ...

# %%
df[df['discount_type'].apply(extract_percentage)==70][df[df['discount_type'].apply(extract_percentage)==70]['age']<=60]
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 50423    50.0      F                블루                무료                그린
# 96726    40.0      M                골드                무료                그린
# 199733   50.0      F                무료               NaN               NaN
# 259411   40.0      M                골드                무료               NaN
# 265603   40.0      F                골드                무료                그린
# 315893   50.0      F                무료               NaN               NaN
# 415261   40.0      F                골드                무료               NaN
# 455399   50.0      M                무료               NaN               NaN
# 470923   40.0      F                무료               NaN               NaN
# 546502   50.0      F                무료               NaN               NaN
# 568749   60.0      F                무료               NaN               NaN
# ...

# %%
(1,1) 1층 A블록 1열 1
